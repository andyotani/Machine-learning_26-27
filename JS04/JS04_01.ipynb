# %% [markdown]
# <a href="https://colab.research.google.com/github/andyotani/Machine-learning_26-27/blob/main/JS04/JS04_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## LAB 1

# %%
# Langkah 1: Persiapan Data
# Download dan letakkan file data yang akan digunakan pada direktori yang sama. Pastikan data telah disimpan dalam format CSV.

# %%
# Langkah 2: Import Library
# import package
import numpy as np
import pandas as pd
# Import library NumPy dan Pandas yang digunakan untuk manipulasi data.

# %%
#Langkah 3: Baca Data
# baca data dari file CSV
data = pd.read_csv('dataset.csv')
